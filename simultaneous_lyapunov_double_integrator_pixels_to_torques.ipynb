# %%
import torch
from torch.autograd import Variable

# %% [markdown]
# ## Get a state of the double integrator
#
# <p align="center">
#   <img src="double_integrator_brick.svg" width="350"/>
# </p>

# %%
### initial state and parameters

## parameters
width  = 10.0 # width of brick in pixels
height = 5.0
t_f = 100     # number of time steps

## state
x    = 30.0 # position to right in pixels
xdot = 0.0  # 

state_initial = torch.FloatTensor([x, xdot])
state_initial = Variable(state_initial, requires_grad=False)
print state_initial
# Out:
# Variable containing:
#  30
#   0
# [torch.FloatTensor of size 2]

# %% [markdown]
# ## Just render double integrator
#
# - Convert state of double integrator to an AABB list of corners in img
# - Find all pixels inside AABB

# %%
import numpy as np
pi = np.pi

def convert_world_to_img_coordinates(world_coordinates):
    return world_coordinates + 50

def torch_flip(two_element_tensor):
    return torch.FloatTensor([two_element_tensor[1],two_element_tensor[0]])
    
def torch_det(A,B):
    return A[0]*B[1] - A[1]*B[0]

def distance_pytorch(A, B, P):
    if (A == B).all() or (B == P).all():
        return 0
    if (torch.acos(torch.FloatTensor([torch.dot((P - A) / (P - A).norm(), 
                                                (B - A) / (B - A).norm())])) > pi/2).all():
        return (P - A).norm()
    
    if (torch.acos(torch.FloatTensor([torch.dot((P - B) / (P - B).norm(), 
                                                (A - B) / (A - B).norm())])) > pi/2).all():
        return (P - B).norm()
    
    return abs(torch_det(A-B, A-P))/(B-A).norm()

def inside_aabb(aabb_corners, P):
    # check x conditions
    if (P[0] < aabb_corners[0][0]).all() or (P[0] > aabb_corners[3][0]).all():
        return False
    
    # check y conditions
    if (P[1] < aabb_corners[0][1]).all() or (P[1] > aabb_corners[3][1]).all():
        return False
    
    return True

def distance_to_aabb(aabb_corners, P):
    # if inside aabb, return 0
    distance_to_left   = distance_pytorch(aabb_corners[0], aabb_corners[1], P)
    distance_to_top    = distance_pytorch(aabb_corners[1], aabb_corners[3], P)
    distance_to_right  = distance_pytorch(aabb_corners[0], aabb_corners[1], P)
    distance_to_bottom = distance_pytorch(aabb_corners[0], aabb_corners[1], P)

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

def where(cond, x_1, x_2):
    cond = cond.float()    
    return (cond * x_1) + ((1-cond) * x_2)

def vectorized_inside_aabb(aabb_corners):
    img = Variable(torch.ones((100,100)), requires_grad=False)
    img[0:int(aabb_corners[0][0]),:] = 0.0
    img[int(aabb_corners[3][0]):,:] = 0.0
    img[:,0:int(aabb_corners[0][1])] = 0.0
    img[:,int(aabb_corners[3][1]):] = 0.0
    return img
    
def double_integrator_state_to_img(state):
    center = Variable(torch.zeros(2), requires_grad = False)
    center[1] = state[0]
    center_in_img = convert_world_to_img_coordinates(center)

    lower_left  = center + Variable(torch.FloatTensor([0,      -width/2]), requires_grad=False)
    upper_left  = center + Variable(torch.FloatTensor([height, -width/2]), requires_grad=False)
    lower_right = center + Variable(torch.FloatTensor([0,       width/2]), requires_grad=False)
    upper_right = center + Variable(torch.FloatTensor([height,  width/2]), requires_grad=False)

    corners = [lower_left, upper_left, lower_right, upper_right]
    corners_in_img = [convert_world_to_img_coordinates(x) for x in corners]
    
    return vectorized_inside_aabb(corners_in_img)

import time; start = time.time()
img = double_integrator_state_to_img(state_initial)
print time.time() - start, " seconds for state to img"
plt.imshow(img.data, cmap=plt.get_cmap('gray_r'))
plt.show()
# Out:
# 0.000494003295898  seconds for state to img
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## State feedback: perform state feedback with just PD

# %%
def pd_origin_controller(state):
    x_desired = 0
    xdot_desired = 0
    diff_pos = (x_desired    - state[0])
    diff_vel = (xdot_desired - state[1])
    u = 1000*diff_pos + 100*diff_vel
    if (u > 500).all():
        u = u*0 + 500  # this trick mantains u as a Variable
    if (u < -500).all():
        u = u*0 -500
    return u

def double_integrator_next_state(state, u):
    deriv = Variable(torch.zeros(2), requires_grad = False)
    deriv[0] = state[1]
    deriv[1] = u
    dt = .01
    next_state = state + deriv*dt
    return next_state

state_tape = []
state_tape.append(state_initial)

for i in range(t_f):
    u = pd_origin_controller(state_tape[-1])
    next_state = double_integrator_next_state(state_tape[-1],u)
    state_tape.append(next_state)
    
print len(state_tape)
# Out:
# 101

# %% [markdown]
# ## Convert states to imgs

# %%
img_tape = []

for i in state_tape:
    img_tape.append(double_integrator_state_to_img(i))
    
print len(img_tape)
# Out:
# 101

# %% [markdown]
# ## Visualize

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib import animation
from IPython.display import HTML

def get_animation(img_tape):
    fig = plt.figure()
    first_img = img_tape[0].data
    im = plt.imshow(first_img, cmap='gist_gray_r')

    def init():
        im.set_data(first_img)

    def animate(i):
        im.set_data(img_tape[i].data)
        return im

    animate = animation.FuncAnimation(fig, animate, init_func=init, frames=len(img_tape), interval=20, blit=True)
    plt.close(fig)
    return animate
    
ani = get_animation(img_tape)
HTML(ani.to_html5_video())
# Out:
# <img src="data:image/png;base64,..." width="640">
# <video width="640" height="480" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# ## Simultaneous search for policy and verifying Lyapunov function
#
# $$\dot{x} = f(x,u)$$
#
# $$ u = \pi_\theta(x)) $$
#
# $$ V(x) = p.s.d. \text{by construction, but parameterized by parameters } \psi $$
#
# $$ \dot{V} = \frac{dV}{dx} \dot{x}$$
# $$ = \big[ \frac{dV}{dx}\big]^T \big[f(x,\pi_{\theta}(x) \big] $$
#
# ### Loss function
#
# $X$ = {$x_1, x_2, ..., x_N$} many samples
#
# $$ L(\theta) = \sum_{i} l(x_i, \theta) $$
#
# \begin{equation}
#   \mathcal{l}(x_i,\theta) =
#   \begin{cases}
#     \dot{V}(x_i, \theta) & \text{if $\dot{V}(x_i, \theta) > 0$} \\
#     0 & \text{otherwise}
#   \end{cases}
# \end{equation}

# %%
x_i = Variable(torch.FloatTensor([1.0, 1.1]), requires_grad=True)
print x_i


P = Variable(torch.FloatTensor([1, 1]), requires_grad=True)
print P
### Step 1: compute V(x)
def compute_V(x):
    '''V(x) = x_1^2 + x_2^2'''
    x_squared = x.pow(2)
    return torch.dot(P, x_squared)

### Step 2: compute dV/dx

### Step 3: initialize policy parameters
K = Variable(torch.FloatTensor([1, 2]), requires_grad=True)
print K

### Step 4: define dynamics function
def dynamics(x):
    xdot = Variable(torch.zeros(2))
    xdot[0] = x[1]
    xdot[1] = -torch.dot(K,x)
    return xdot
    
xdot = dynamics(x_i)
print xdot

### Step 5: compute Vdot

def compute_Vdot(x):
    V = compute_V(x)
    V.backward(torch.FloatTensor([1.0]),retain_graph=True)
    jacobian_x = Variable(x.grad.data)
    f = dynamics(x)
    Vdot = torch.dot(jacobian_x,f)
    return Vdot
    
Vdot = compute_Vdot(x_i)
print Vdot
Vdot.backward()
# Out:
# Variable containing:
#  1.0000
#  1.1000
# [torch.FloatTensor of size 2]
#
# Variable containing:
#  1
#  1
# [torch.FloatTensor of size 2]
#
# Variable containing:
#  1
#  2
# [torch.FloatTensor of size 2]
#
# Variable containing:
#  1.1000
# -3.2000
# [torch.FloatTensor of size 2]
#
# Variable containing:
# -4.8400
# [torch.FloatTensor of size 1]

# %% [markdown]
# ## First let's verify, no synthesis
#
# K = [1, 2] and P = [1, 1] should be stable

# %%
K = Variable(torch.FloatTensor([1, 2]), requires_grad=True)
P = Variable(torch.FloatTensor([1, 1]), requires_grad=True)
for i in range(10000):
    x_i = Variable(torch.randn(2), requires_grad=True)
    Vdot = compute_Vdot(x_i)
    if Vdot.data[0] > 0:
        print "false, counterexample found: ", x_i
        break

# %% [markdown]
# ## Now let's search for K, from an initialization not stable

# %%
P = Variable(torch.rand(2), requires_grad=True)
K = Variable(torch.randn(2), requires_grad=True)

print "Initial P", P
print "Initial K", K


for i in range(10000):
    x_i = Variable(torch.randn(2), requires_grad=True)
    Vdot = compute_Vdot(x_i)
    if Vdot.data[0] > 0:
        print "false, counterexample found: ", x_i
        break
# Out:
# Initial P Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# Initial K Variable containing:
#  0.3784
# -1.2072
# [torch.FloatTensor of size 2]
#
# false, counterexample found:  Variable containing:
# -0.1828
# -0.2066
# [torch.FloatTensor of size 2]

# %%
## optimization plotting tool

cost_current_iteration = 0
cost_history = []
cost_iteration_number_history = []

f, (cost_axis) = plt.subplots(1, 1)

cost_axis.plot(cost_iteration_number_history, cost_history)
cost_axis.set_title('Running cost')

plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
## optimize

num_iterations = 1000
num_samples_per_iteration = 1000
step_rate = 1e-2

# K has already been initialized above, and initial policy visualized

import time

for cost_iteration in range(num_iterations):
    start = time.time()
    
    cost = 0
    
    for i in range(1000):
        x_i = Variable(torch.randn(2), requires_grad=True)
        Vdot = compute_Vdot(x_i)
        cost += Vdot.clamp(min=0)
        
    ## Automatically differentiate
    cost.backward()

    # Update K via gradient descent
    K.data -= step_rate * K.grad.data
      
    # Manually zero the gradients after running the backward pass
    K.grad.data.zero_()
    
    print time.time() - start, "is time for one step of grad descent"
    print 
    print cost.data[0]
    
    # handle plotting
    cost_history.append(cost.data[0])
    cost_iteration_number_history.append(cost_iteration)
    
    if cost_iteration % 1 == 0:
        cost_axis.lines[0].set_xdata(cost_iteration_number_history)
        cost_axis.lines[0].set_ydata(cost_history)
        cost_axis.relim()
        cost_axis.autoscale_view()
        cost_axis.figure.canvas.draw()
        
    if cost.data[0] == 0:
        break
        
    print P
# Out:
# 0.319458007812 is time for one step of grad descent
#
# 2109.2043457
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.382306098938 is time for one step of grad descent
#
# 0.109304487705
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.32053899765 is time for one step of grad descent
#
# 0.118018135428
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.306224107742 is time for one step of grad descent
#
# 0.0949168279767
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.358834028244 is time for one step of grad descent
#
# 0.04513765499
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.304999113083 is time for one step of grad descent
#
# 0.0723952427506
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.396685838699 is time for one step of grad descent
#
# 0.061402477324
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.317823886871 is time for one step of grad descent
#
# 0.021198136732
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.372476100922 is time for one step of grad descent
#
# 0.0166828166693
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.348731994629 is time for one step of grad descent
#
# 0.0378928147256
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.344491958618 is time for one step of grad descent
#
# 0.0348817557096
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.382550001144 is time for one step of grad descent
#
# 0.0251118931919
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.373372077942 is time for one step of grad descent
#
# 0.0217226482928
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.328317165375 is time for one step of grad descent
#
# 0.0597638525069
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.373594045639 is time for one step of grad descent
#
# 0.0540410615504
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.326421022415 is time for one step of grad descent
#
# 0.0232143998146
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.368345975876 is time for one step of grad descent
#
# 0.0103968959302
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.324084997177 is time for one step of grad descent
#
# 0.00678429566324
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.313179016113 is time for one step of grad descent
#
# 0.0301574058831
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.405951023102 is time for one step of grad descent
#
# 0.0172197129577
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.292901992798 is time for one step of grad descent
#
# 0.0222013350576
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.354934930801 is time for one step of grad descent
#
# 0.0533227771521
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.331238985062 is time for one step of grad descent
#
# 0.0616990737617
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.377028942108 is time for one step of grad descent
#
# 0.0320237129927
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.35555100441 is time for one step of grad descent
#
# 0.0315501838923
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.339308023453 is time for one step of grad descent
#
# 0.0382193885744
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.312408924103 is time for one step of grad descent
#
# 0.0466536767781
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.377114057541 is time for one step of grad descent
#
# 0.0233998969197
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.369174003601 is time for one step of grad descent
#
# 0.0442982465029
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.332202911377 is time for one step of grad descent
#
# 0.0190009139478
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.328698158264 is time for one step of grad descent
#
# 0.0184992030263
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.373233795166 is time for one step of grad descent
#
# 0.0266669020057
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.331909894943 is time for one step of grad descent
#
# 0.0124853085726
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.330837011337 is time for one step of grad descent
#
# 0.0112858600914
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.32793712616 is time for one step of grad descent
#
# 0.0120684755966
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.339597940445 is time for one step of grad descent
#
# 0.0157582443208
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.310475826263 is time for one step of grad descent
#
# 0.0317493155599
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.303679943085 is time for one step of grad descent
#
# 0.0195533875376
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.318843841553 is time for one step of grad descent
#
# 0.0133771337569
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.330942153931 is time for one step of grad descent
#
# 0.00612879917026
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.333384037018 is time for one step of grad descent
#
# 0.0101617444307
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.367620944977 is time for one step of grad descent
#
# 0.0337298251688
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.384971857071 is time for one step of grad descent
#
# 0.0135364858434
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.322230100632 is time for one step of grad descent
#
# 0.0256085209548
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.337671041489 is time for one step of grad descent
#
# 0.000456366629805
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.370676994324 is time for one step of grad descent
#
# 0.0154340993613
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.335574865341 is time for one step of grad descent
#
# 0.0351498201489
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.327411174774 is time for one step of grad descent
#
# 0.028566043824
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.324429035187 is time for one step of grad descent
#
# 0.0106048230082
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.342194080353 is time for one step of grad descent
#
# 0.0158520489931
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.394556999207 is time for one step of grad descent
#
# 0.0213206224144
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.276859998703 is time for one step of grad descent
#
# 0.0315952636302
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.36544084549 is time for one step of grad descent
#
# 0.0222895033658
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.312804937363 is time for one step of grad descent
#
# 0.0334837809205
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.345570087433 is time for one step of grad descent
#
# 0.0124384267256
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.310392141342 is time for one step of grad descent
#
# 0.00750223081559
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.270933151245 is time for one step of grad descent
#
# 0.00611127959564
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.311593055725 is time for one step of grad descent
#
# 0.0167828369886
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.298405885696 is time for one step of grad descent
#
# 0.00661268550903
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.28613781929 is time for one step of grad descent
#
# 0.00837146677077
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
# 0.301453113556 is time for one step of grad descent
#
# 0.0233279969543
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.336580038071 is time for one step of grad descent
#
# 0.0178915876895
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.337780952454 is time for one step of grad descent
#
# 0.0171985700727
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.3303399086 is time for one step of grad descent
#
# 0.0117644974962
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.279760122299 is time for one step of grad descent
#
# 0.0371313691139
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.367749214172 is time for one step of grad descent
#
# 0.0278883893043
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.347629070282 is time for one step of grad descent
#
# 0.0230914205313
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.331997871399 is time for one step of grad descent
#
# 0.00901301205158
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.338494062424 is time for one step of grad descent
#
# 0.0151518573985
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.312522888184 is time for one step of grad descent
#
# 0.0171018149704
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.376597881317 is time for one step of grad descent
#
# 0.0164624750614
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.365708112717 is time for one step of grad descent
#
# 0.00471998006105
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.370527982712 is time for one step of grad descent
#
# 0.00371744250879
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.362432956696 is time for one step of grad descent
#
# 0.0265235546976
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.309209108353 is time for one step of grad descent
#
# 0.00560032622889
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.319713830948 is time for one step of grad descent
#
# 0.0164434276521
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.344150066376 is time for one step of grad descent
#
# 0.0152457822114
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.330215930939 is time for one step of grad descent
#
# 0.0104565164074
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.322520017624 is time for one step of grad descent
#
# 0.00374359171838
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.321167945862 is time for one step of grad descent
#
# 0.0029312283732
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.286325931549 is time for one step of grad descent
#
# 0.0111149419099
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.329591989517 is time for one step of grad descent
#
# 0.0172687992454
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.325414180756 is time for one step of grad descent
#
# 0.0241145938635
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.33283495903 is time for one step of grad descent
#
# 0.0154414605349
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.360253810883 is time for one step of grad descent
#
# 0.0186563078314
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.358556032181 is time for one step of grad descent
#
# 0.0141537636518
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.32608795166 is time for one step of grad descent
#
# 0.00496489973739
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.331161975861 is time for one step of grad descent
#
# 0.00265550706536
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.362323999405 is time for one step of grad descent
#
# 0.0194307994097
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.316694021225 is time for one step of grad descent
#
# 0.00937024876475
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.269278049469 is time for one step of grad descent
#
# 0.00122116878629
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.35224199295 is time for one step of grad descent
#
# 0.0113215995952
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.366712093353 is time for one step of grad descent
#
# 0.0219999905676
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.329136133194 is time for one step of grad descent
#
# 0.0121838543564
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.393733024597 is time for one step of grad descent
#
# 0.0156038794667
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.324936151505 is time for one step of grad descent
#
# 0.0152217503637
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.342438936234 is time for one step of grad descent
#
# 0.00382664334029
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.365120172501 is time for one step of grad descent
#
# 0.008160921745
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.382267951965 is time for one step of grad descent
#
# 0.00692324712873
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.37416601181 is time for one step of grad descent
#
# 0.0111724212766
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.338615894318 is time for one step of grad descent
#
# 0.0106917927042
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.323799133301 is time for one step of grad descent
#
# 0.0113921947777
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.373729944229 is time for one step of grad descent
#
# 0.00278890505433
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.322271823883 is time for one step of grad descent
#
# 0.00559834344313
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.362445116043 is time for one step of grad descent
#
# 0.0112381093204
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.362905025482 is time for one step of grad descent
#
# 0.00185341376346
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.332445859909 is time for one step of grad descent
#
# 0.000278596766293
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.304039955139 is time for one step of grad descent
#
# 0.0137942992151
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.392242193222 is time for one step of grad descent
#
# 0.0175312757492
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.318806886673 is time for one step of grad descent
#
# 0.00343497633003
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.348991155624 is time for one step of grad descent
#
# 0.00809140410274
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.37287902832 is time for one step of grad descent
#
# 0.00591594865546
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.324290990829 is time for one step of grad descent
#
# 0.000871265481692
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.291398048401 is time for one step of grad descent
#
# 0.00444028619677
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.377682924271 is time for one step of grad descent
#
# 0.0245474949479
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.337176084518 is time for one step of grad descent
#
# 0.00224515236914
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.322522878647 is time for one step of grad descent
#
# 0.00259816786274
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.344094991684 is time for one step of grad descent
#
# 0.00669543771073
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.332049131393 is time for one step of grad descent
#
# 0.00476865563542
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.361762046814 is time for one step of grad descent
#
# 0.00724096642807
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
# 0.330213069916 is time for one step of grad descent
#
# 0.00381839321926
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.319185972214 is time for one step of grad descent
#
# 0.0116736777127
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.317677021027 is time for one step of grad descent
#
# 0.00158820836805
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.312121152878 is time for one step of grad descent
#
# 0.00754932081327
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.342026948929 is time for one step of grad descent
#
# 0.0145286330953
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.379408121109 is time for one step of grad descent
#
# 0.000867718597874
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.318830013275 is time for one step of grad descent
#
# 0.00715116132051
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.369006872177 is time for one step of grad descent
#
# 0.00484589906409
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.36402797699 is time for one step of grad descent
#
# 0.00666794972494
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.313788890839 is time for one step of grad descent
#
# 0.011213070713
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.307861089706 is time for one step of grad descent
#
# 0.00669930130243
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.334939002991 is time for one step of grad descent
#
# 0.00642517022789
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.341701984406 is time for one step of grad descent
#
# 0.000317561673
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.332059144974 is time for one step of grad descent
#
# 0.0108718955889
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.381963014603 is time for one step of grad descent
#
# 0.00353746162727
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.365025997162 is time for one step of grad descent
#
# 0.0053790891543
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.330909013748 is time for one step of grad descent
#
# 0.000868607952725
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.31246304512 is time for one step of grad descent
#
# 0.00730173382908
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.307044029236 is time for one step of grad descent
#
# 0.014838068746
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.353832006454 is time for one step of grad descent
#
# 0.00236999406479
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.260882854462 is time for one step of grad descent
#
# 0.00502796145156
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.320756912231 is time for one step of grad descent
#
# 0.00473359134048
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.382700920105 is time for one step of grad descent
#
# 0.00416814628989
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.316061019897 is time for one step of grad descent
#
# 0.00537078268826
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.322339057922 is time for one step of grad descent
#
# 0.00320576294325
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.337207078934 is time for one step of grad descent
#
# 0.00604785233736
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.332550048828 is time for one step of grad descent
#
# 0.00511310901493
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.384262084961 is time for one step of grad descent
#
# 0.00432153278962
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.355401992798 is time for one step of grad descent
#
# 0.00894722342491
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.333741903305 is time for one step of grad descent
#
# 0.00196079094894
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.355599880219 is time for one step of grad descent
#
# 0.00525889638811
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.340297937393 is time for one step of grad descent
#
# 0.010994264856
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.366641998291 is time for one step of grad descent
#
# 0.00320305395871
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.29162311554 is time for one step of grad descent
#
# 0.000280839391053
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.318972110748 is time for one step of grad descent
#
# 0.00183156644925
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.318922996521 is time for one step of grad descent
#
# 0.00258500827476
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.378062009811 is time for one step of grad descent
#
# 0.00144931906834
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.443104982376 is time for one step of grad descent
#
# 0.000622847233899
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.343865871429 is time for one step of grad descent
#
# 0.00132717331871
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.331328868866 is time for one step of grad descent
#
# 0.00478516612202
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.386056184769 is time for one step of grad descent
#
# 6.38467281533e-06
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.326148033142 is time for one step of grad descent
#
# 0.00481864763424
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.336241960526 is time for one step of grad descent
#
# 0.00806433334947
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.370367050171 is time for one step of grad descent
#
# 0.000253516773228
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.380205154419 is time for one step of grad descent
#
# 0.00321569154039
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.34493303299 is time for one step of grad descent
#
# 0.0039916750975
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.338559865952 is time for one step of grad descent
#
# 0.00948714651167
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.332548856735 is time for one step of grad descent
#
# 0.0040534734726
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.37119102478 is time for one step of grad descent
#
# 0.0117097273469
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.337606906891 is time for one step of grad descent
#
# 0.00807590410113
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.34073805809 is time for one step of grad descent
#
# 0.00439829332754
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.333703994751 is time for one step of grad descent
#
# 0.00661112880334
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.339794874191 is time for one step of grad descent
#
# 0.00232781097293
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.341711044312 is time for one step of grad descent
#
# 0.00426321011037
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.337302923203 is time for one step of grad descent
#
# 0.00117625575513
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.327673912048 is time for one step of grad descent
#
# 0.00902070477605
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.380266904831 is time for one step of grad descent
#
# 0.00322144455276
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.375766992569 is time for one step of grad descent
#
# 0.00366654479876
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.307046890259 is time for one step of grad descent
#
# 8.37448533275e-05
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.316682815552 is time for one step of grad descent
#
# 0.00276071019471
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
# 0.391999006271 is time for one step of grad descent
#
# 0.00294197816402
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.332127094269 is time for one step of grad descent
#
# 0.000491960672662
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.336951971054 is time for one step of grad descent
#
# 0.000357989629265
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.336524963379 is time for one step of grad descent
#
# 0.000548778101802
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.340559005737 is time for one step of grad descent
#
# 0.00475642457604
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.312879085541 is time for one step of grad descent
#
# 0.00214819191024
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.340881109238 is time for one step of grad descent
#
# 0.000206109136343
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.336326122284 is time for one step of grad descent
#
# 0.00228414032608
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]
#
# 0.37208199501 is time for one step of grad descent
#
# 0.0

# %%
print K
print P
# Out:
# Variable containing:
#   0.2410
#  16.2734
# [torch.FloatTensor of size 2]
#
# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]

# %% [markdown]
# ## Analytical double integrator Lyapunov
#
# $$x =
#        \begin{bmatrix} x_1 \\ x_2
#         \end{bmatrix} $$
#
# $$\dot{x} = f(x,u) =
#        \begin{bmatrix} x_2 \\ u
#         \end{bmatrix} $$
#
# Policy
#
# $$ u = \pi_K(x) = -K^Tx = - k_1x_1 - k_2x_2$$
#
# Lyapunov
#
# $$V(x) = P^Tx = p_1x_1^2 + p_2x_2^2 = \text{p.s.d. by construction}$$
#
# $$\dot{V}(x) = \bigg[ \frac{\partial V}{\partial x}\bigg]^T \big[f(x,\pi_K(x) \big] $$
#
# $$ = \begin{bmatrix} 2p_1x_1 \\ 2p_2x_2
#         \end{bmatrix}^T \begin{bmatrix} x_2 \\ -k_1x_1 - k_2x_2
#         \end{bmatrix} $$
#
# $$ =  2p_1x_1x_2 + 2p_2x_2( - k_1x_1 - k_2x_2) $$
#
# $$ =  2p_1x_1x_2 - 2p_2k_1x_1x_2 - 2p_2k_2x_2^2 $$
#
# We need both terms to be negative semidefinite:
#
# $$ =  2x_1x_2(p_1 - p_2k_1 ) - 2p_2k_2x_2^2 $$
#
# Therefore conditions are:
#
# a) $p_1 = p_2k_1$
#
# b) $k_2 > 0$ ($p_2$ already must be $> 0$)

# %%
# condition (a):  p_1 - p_2*k_1
print P[0] - P[1]*K[0]

# condition (b): k_2 > 0
print K[1]
# Out:
# Variable containing:
#  0.1356
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  16.2734
# [torch.FloatTensor of size 1]

# %%
# Note: first time I ended up with these values:

# print K
# print P
# Variable containing:
#   0.2410
#  16.2734
# [torch.FloatTensor of size 2]

# Variable containing:
#  0.3484
#  0.8831
# [torch.FloatTensor of size 2]

#Which gave only:

# # condition (a):  p_1 - p_2*k_1
# print P[0] - P[1]*K[0]

# # condition (b): k_2 > 0
# print K[1]

# Variable containing:
#  0.1356
# [torch.FloatTensor of size 1]

# Variable containing:
#  16.2734
# [torch.FloatTensor of size 1]

# But this was Vdot negative semidefinite over all samples, since k_2 was so large it could outweigh the first term
